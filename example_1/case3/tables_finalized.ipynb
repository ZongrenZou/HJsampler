# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colormaps
import scipy.io as sio
from tqdm import trange
import ot

# %% [markdown]
# #### Case 1

# %%
sgm = sio.loadmat("./outputs/sgm1.mat")["samples"]
analytic = sio.loadmat("./outputs/analytic1.mat")["samples"]
reference = sio.loadmat("./outputs/exact1.mat")["samples"]

# %%
ot.sliced_wasserstein_distance(
    sgm, reference, n_projections=50, p=1,
)
# Out:
# 0.012621292138942782

# %%
ot.sliced_wasserstein_distance(
    analytic, reference, n_projections=50, p=1,
)
# Out:
# 0.0007223371064100332

# %% [markdown]
# #### Case 2

# %%
sgm = sio.loadmat("./outputs/sgm2.mat")["samples"]
analytic = sio.loadmat("./outputs/analytic2.mat")["samples"]
reference = sio.loadmat("./outputs/exact2.mat")["samples"]

# %%
ot.sliced_wasserstein_distance(
    sgm, reference, n_projections=50, p=1,
)
# Out:
# 0.0056428141627850315

# %%
ot.sliced_wasserstein_distance(
    analytic, reference, n_projections=50, p=1,
)
# Out:
# 0.0006983709956550417

# %% [markdown]
# #### Case 3

# %%
sgm = sio.loadmat("./outputs/sgm6.mat")["samples"]
analytic = sio.loadmat("./outputs/analytic4.mat")["samples"]
reference = sio.loadmat("./outputs/exact4.mat")["samples"]

# %%
ot.sliced_wasserstein_distance(
    sgm, reference, n_projections=50, p=1,
)
# Out:
# 0.00246442678708791

# %%
ot.sliced_wasserstein_distance(
    analytic, reference, n_projections=50, p=1,
)
# Out:
# 0.0008026220560582531

# %% [markdown]
# #### Case 4

# %%
sgm = sio.loadmat("./outputs/sgm5.mat")["samples"]
analytic = sio.loadmat("./outputs/analytic5.mat")["samples"]
reference = sio.loadmat("./outputs/exact5.mat")["samples"]

# %%
ot.sliced_wasserstein_distance(
    sgm, reference, n_projections=50, p=1,
)
# Out:
# 0.0031430364772395726

# %%
ot.sliced_wasserstein_distance(
    analytic, reference, n_projections=50, p=1,
)
# Out:
# 0.000660384687665563
